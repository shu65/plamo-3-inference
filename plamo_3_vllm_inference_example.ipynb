# %% [markdown]
# <a href="https://colab.research.google.com/github/shu65/plamo-3-inference/blob/main/plamo_3_vllm_inference_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --no-cache git+https://github.com/pfnet-research/vllm-plamo3-plugin.git
# Out:
# Collecting git+https://github.com/pfnet-research/vllm-plamo3-plugin.git
#   Cloning https://github.com/pfnet-research/vllm-plamo3-plugin.git to /tmp/pip-req-build-4bt1rli2
#   Running command git clone --filter=blob:none --quiet https://github.com/pfnet-research/vllm-plamo3-plugin.git /tmp/pip-req-build-4bt1rli2
#   Resolved https://github.com/pfnet-research/vllm-plamo3-plugin.git to commit e0079ac2ccaa82b80dc3348a4c8c46a93ce06eb9
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: vllm>=0.11.0 in /usr/local/lib/python3.12/dist-packages (from vllm_plamo3==0.0.0) (0.11.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from vllm>=0.11.0->vllm_plamo3==0.0.0) (2024.11.6)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.12/dist-packages (from vllm>=0.11.0->vllm_plamo3==0.0.0) (5.5.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from vllm>=0.11.0->vllm_plamo3==0.0.0) (5.9.5)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (from vllm>=0.11.0->vllm_plamo3==0.0.0) (0.2.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from vllm>=0.11.0->vllm_plamo3==0.0.0) (2.0.2)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.12/dist-packages (from vllm>=0.11.0->vllm_plamo3==0.0.0) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from vllm>=0.11.0->vllm_plamo3==0.0.0) (4.67.1)
# Requirement already satisfied: blake3 in /usr/local/lib/python3.12/dist-packages (from vllm>=0.11.0->vllm_plamo3==0.0.0) (1.0.8)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.12/dist-packages (from vllm>=0.11.0->vllm_plamo3==0.0.0) (9.0.0)
# Requirement already satisfied: transformers>=4.55.2 in /usr/local/lib/python3.12/dist-packages (from vllm>=0.11.0->vllm_plamo3==0.0.0) (4.57.1)
# Requirement already satisfied: tokenizers>=0.21.1 in /usr/local/lib/python3.12/dist-packages (from vllm>=0.11.0->vllm_plamo3==0.0.0) (0.22.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from vllm>=0.11.0->vllm_plamo3==0.0.0) (5.29.5)
# Requirement already satisfied: fastapi>=0.115.0 in /usr/local/lib/python3.12/dist-packages (from fastapi[standard]>=0.115.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (0.121.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from vllm>=0.11.0->vllm_plamo3==0.0.0) (3.13.2)
# Requirement already satisfied: openai>=1.99.1 in /usr/local/lib/python3.12/dist-packages (from vllm>=0.11.0->vllm_plamo3==0.0.0) (1.109.1)
# Requirement already satisfied: pydantic>=2.11.7 in /usr/local/lib/python3.12/dist-packages (from vllm>=0.11.0->vllm_plamo3==0.0.0) (2.11.10)
# Requirement already satisfied: prometheus_client>=0.18.0 in /usr/local/lib/python3.12/dist-packages (from vllm>=0.11.0->vllm_plamo3==0.0.0) (0.23.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from vllm>=0.11.0->vllm_plamo3==0.0.0) (11.3.0)
# Requirement already satisfied: prometheus-fastapi-instrumentator>=7.0.0 in /usr/local/lib/python3.12/dist-packages (from vllm>=0.11.0->vllm_plamo3==0.0.0) (7.1.0)
# Requirement already satisfied: tiktoken>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from vllm>=0.11.0->vllm_plamo3==0.0.0) (0.12.0)
# Requirement already satisfied: lm-format-enforcer==0.11.3 in /usr/local/lib/python3.12/dist-packages (from vllm>=0.11.0->vllm_plamo3==0.0.0) (0.11.3)
# Requirement already satisfied: llguidance<0.8.0,>=0.7.11 in /usr/local/lib/python3.12/dist-packages (from vllm>=0.11.0->vllm_plamo3==0.0.0) (0.7.30)
# Requirement already satisfied: outlines_core==0.2.11 in /usr/local/lib/python3.12/dist-packages (from vllm>=0.11.0->vllm_plamo3==0.0.0) (0.2.11)
# Requirement already satisfied: diskcache==5.6.3 in /usr/local/lib/python3.12/dist-packages (from vllm>=0.11.0->vllm_plamo3==0.0.0) (5.6.3)
# Requirement already satisfied: lark==1.2.2 in /usr/local/lib/python3.12/dist-packages (from vllm>=0.11.0->vllm_plamo3==0.0.0) (1.2.2)
# Requirement already satisfied: xgrammar==0.1.25 in /usr/local/lib/python3.12/dist-packages (from vllm>=0.11.0->vllm_plamo3==0.0.0) (0.1.25)
# Requirement already satisfied: typing_extensions>=4.10 in /usr/local/lib/python3.12/dist-packages (from vllm>=0.11.0->vllm_plamo3==0.0.0) (4.15.0)
# Requirement already satisfied: filelock>=3.16.1 in /usr/local/lib/python3.12/dist-packages (from vllm>=0.11.0->vllm_plamo3==0.0.0) (3.20.0)
# Requirement already satisfied: partial-json-parser in /usr/local/lib/python3.12/dist-packages (from vllm>=0.11.0->vllm_plamo3==0.0.0) (0.2.1.1.post6)
# Requirement already satisfied: pyzmq>=25.0.0 in /usr/local/lib/python3.12/dist-packages (from vllm>=0.11.0->vllm_plamo3==0.0.0) (26.2.1)
# Requirement already satisfied: msgspec in /usr/local/lib/python3.12/dist-packages (from vllm>=0.11.0->vllm_plamo3==0.0.0) (0.19.0)
# Requirement already satisfied: gguf>=0.13.0 in /usr/local/lib/python3.12/dist-packages (from vllm>=0.11.0->vllm_plamo3==0.0.0) (0.17.1)
# Requirement already satisfied: mistral_common>=1.8.2 in /usr/local/lib/python3.12/dist-packages (from mistral_common[audio,image]>=1.8.2->vllm>=0.11.0->vllm_plamo3==0.0.0) (1.8.5)
# Requirement already satisfied: opencv-python-headless>=4.11.0 in /usr/local/lib/python3.12/dist-packages (from vllm>=0.11.0->vllm_plamo3==0.0.0) (4.12.0.88)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from vllm>=0.11.0->vllm_plamo3==0.0.0) (6.0.3)
# Requirement already satisfied: six>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from vllm>=0.11.0->vllm_plamo3==0.0.0) (1.17.0)
# Requirement already satisfied: setuptools<80,>=77.0.3 in /usr/local/lib/python3.12/dist-packages (from vllm>=0.11.0->vllm_plamo3==0.0.0) (79.0.1)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from vllm>=0.11.0->vllm_plamo3==0.0.0) (0.8.1)
# Requirement already satisfied: compressed-tensors==0.11.0 in /usr/local/lib/python3.12/dist-packages (from vllm>=0.11.0->vllm_plamo3==0.0.0) (0.11.0)
# Requirement already satisfied: depyf==0.19.0 in /usr/local/lib/python3.12/dist-packages (from vllm>=0.11.0->vllm_plamo3==0.0.0) (0.19.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from vllm>=0.11.0->vllm_plamo3==0.0.0) (3.1.2)
# Requirement already satisfied: watchfiles in /usr/local/lib/python3.12/dist-packages (from vllm>=0.11.0->vllm_plamo3==0.0.0) (1.1.1)
# Requirement already satisfied: python-json-logger in /usr/local/lib/python3.12/dist-packages (from vllm>=0.11.0->vllm_plamo3==0.0.0) (4.0.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from vllm>=0.11.0->vllm_plamo3==0.0.0) (1.16.3)
# Requirement already satisfied: ninja in /usr/local/lib/python3.12/dist-packages (from vllm>=0.11.0->vllm_plamo3==0.0.0) (1.13.0)
# Requirement already satisfied: pybase64 in /usr/local/lib/python3.12/dist-packages (from vllm>=0.11.0->vllm_plamo3==0.0.0) (1.4.2)
# Requirement already satisfied: cbor2 in /usr/local/lib/python3.12/dist-packages (from vllm>=0.11.0->vllm_plamo3==0.0.0) (5.7.1)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.12/dist-packages (from vllm>=0.11.0->vllm_plamo3==0.0.0) (1.3.7)
# Requirement already satisfied: openai-harmony>=0.0.3 in /usr/local/lib/python3.12/dist-packages (from vllm>=0.11.0->vllm_plamo3==0.0.0) (0.0.8)
# Requirement already satisfied: numba==0.61.2 in /usr/local/lib/python3.12/dist-packages (from vllm>=0.11.0->vllm_plamo3==0.0.0) (0.61.2)
# Requirement already satisfied: ray>=2.48.0 in /usr/local/lib/python3.12/dist-packages (from ray[cgraph]>=2.48.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (2.51.1)
# Requirement already satisfied: torch==2.8.0 in /usr/local/lib/python3.12/dist-packages (from vllm>=0.11.0->vllm_plamo3==0.0.0) (2.8.0+cu126)
# Requirement already satisfied: torchaudio==2.8.0 in /usr/local/lib/python3.12/dist-packages (from vllm>=0.11.0->vllm_plamo3==0.0.0) (2.8.0+cu126)
# Requirement already satisfied: torchvision==0.23.0 in /usr/local/lib/python3.12/dist-packages (from vllm>=0.11.0->vllm_plamo3==0.0.0) (0.23.0+cu126)
# Requirement already satisfied: xformers==0.0.32.post1 in /usr/local/lib/python3.12/dist-packages (from vllm>=0.11.0->vllm_plamo3==0.0.0) (0.0.32.post1)
# Requirement already satisfied: frozendict in /usr/local/lib/python3.12/dist-packages (from compressed-tensors==0.11.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (2.4.6)
# Requirement already satisfied: astor in /usr/local/lib/python3.12/dist-packages (from depyf==0.19.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (0.8.1)
# Requirement already satisfied: dill in /usr/local/lib/python3.12/dist-packages (from depyf==0.19.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (0.3.8)
# Requirement already satisfied: interegular>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from lm-format-enforcer==0.11.3->vllm>=0.11.0->vllm_plamo3==0.0.0) (0.3.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from lm-format-enforcer==0.11.3->vllm>=0.11.0->vllm_plamo3==0.0.0) (25.0)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba==0.61.2->vllm>=0.11.0->vllm_plamo3==0.0.0) (0.44.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (3.4.0)
# Requirement already satisfied: starlette<0.50.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.115.0->fastapi[standard]>=0.115.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (0.49.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.115.0->fastapi[standard]>=0.115.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (0.0.4)
# Requirement already satisfied: fastapi-cli>=0.0.8 in /usr/local/lib/python3.12/dist-packages (from fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (0.0.16)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from fastapi[standard]>=0.115.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (0.28.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.12/dist-packages (from fastapi[standard]>=0.115.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (0.0.20)
# Requirement already satisfied: email-validator>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from fastapi[standard]>=0.115.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (2.3.0)
# Requirement already satisfied: uvicorn>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (0.38.0)
# Requirement already satisfied: jsonschema>=4.21.1 in /usr/local/lib/python3.12/dist-packages (from mistral_common>=1.8.2->mistral_common[audio,image]>=1.8.2->vllm>=0.11.0->vllm_plamo3==0.0.0) (4.25.1)
# Requirement already satisfied: pydantic-extra-types>=2.10.5 in /usr/local/lib/python3.12/dist-packages (from pydantic-extra-types[pycountry]>=2.10.5->mistral_common>=1.8.2->mistral_common[audio,image]>=1.8.2->vllm>=0.11.0->vllm_plamo3==0.0.0) (2.10.6)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.99.1->vllm>=0.11.0->vllm_plamo3==0.0.0) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.99.1->vllm>=0.11.0->vllm_plamo3==0.0.0) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from openai>=1.99.1->vllm>=0.11.0->vllm_plamo3==0.0.0) (0.12.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai>=1.99.1->vllm>=0.11.0->vllm_plamo3==0.0.0) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.11.7->vllm>=0.11.0->vllm_plamo3==0.0.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.11.7->vllm>=0.11.0->vllm_plamo3==0.0.0) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.11.7->vllm>=0.11.0->vllm_plamo3==0.0.0) (0.4.2)
# Requirement already satisfied: click!=8.3.0,>=7.0 in /usr/local/lib/python3.12/dist-packages (from ray>=2.48.0->ray[cgraph]>=2.48.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (8.2.1)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ray>=2.48.0->ray[cgraph]>=2.48.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (1.1.2)
# Requirement already satisfied: cupy-cuda12x in /usr/local/lib/python3.12/dist-packages (from ray[cgraph]>=2.48.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (13.6.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (2025.10.5)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /usr/local/lib/python3.12/dist-packages (from tokenizers>=0.21.1->vllm>=0.11.0->vllm_plamo3==0.0.0) (0.36.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.55.2->vllm>=0.11.0->vllm_plamo3==0.0.0) (0.6.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->vllm>=0.11.0->vllm_plamo3==0.0.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->vllm>=0.11.0->vllm_plamo3==0.0.0) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->vllm>=0.11.0->vllm_plamo3==0.0.0) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->vllm>=0.11.0->vllm_plamo3==0.0.0) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->vllm>=0.11.0->vllm_plamo3==0.0.0) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->vllm>=0.11.0->vllm_plamo3==0.0.0) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->vllm>=0.11.0->vllm_plamo3==0.0.0) (1.22.0)
# Requirement already satisfied: dnspython>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from email-validator>=2.0.0->fastapi[standard]>=0.115.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (2.8.0)
# Requirement already satisfied: typer>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (0.20.0)
# Requirement already satisfied: rich-toolkit>=0.14.8 in /usr/local/lib/python3.12/dist-packages (from fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (0.15.1)
# Requirement already satisfied: fastapi-cloud-cli>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (0.3.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.23.0->fastapi[standard]>=0.115.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->fastapi[standard]>=0.115.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.21.1->vllm>=0.11.0->vllm_plamo3==0.0.0) (1.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch==2.8.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (3.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.21.1->mistral_common>=1.8.2->mistral_common[audio,image]>=1.8.2->vllm>=0.11.0->vllm_plamo3==0.0.0) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.21.1->mistral_common>=1.8.2->mistral_common[audio,image]>=1.8.2->vllm>=0.11.0->vllm_plamo3==0.0.0) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.21.1->mistral_common>=1.8.2->mistral_common[audio,image]>=1.8.2->vllm>=0.11.0->vllm_plamo3==0.0.0) (0.28.0)
# Requirement already satisfied: pycountry>=23 in /usr/local/lib/python3.12/dist-packages (from pydantic-extra-types[pycountry]>=2.10.5->mistral_common>=1.8.2->mistral_common[audio,image]>=1.8.2->vllm>=0.11.0->vllm_plamo3==0.0.0) (24.6.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch==2.8.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (1.3.0)
# Requirement already satisfied: httptools>=0.6.3 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (0.7.1)
# Requirement already satisfied: python-dotenv>=0.13 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (1.2.1)
# Requirement already satisfied: uvloop>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (0.22.1)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]>=0.115.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (15.0.1)
# Requirement already satisfied: fastrlock>=0.5 in /usr/local/lib/python3.12/dist-packages (from cupy-cuda12x->ray[cgraph]>=2.48.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (0.8.3)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.12/dist-packages (from mistral_common>=1.8.2->mistral_common[audio,image]>=1.8.2->vllm>=0.11.0->vllm_plamo3==0.0.0) (0.13.1)
# Requirement already satisfied: soxr>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from mistral_common>=1.8.2->mistral_common[audio,image]>=1.8.2->vllm>=0.11.0->vllm_plamo3==0.0.0) (1.0.0)
# Requirement already satisfied: rignore>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (0.7.6)
# Requirement already satisfied: sentry-sdk>=2.20.0 in /usr/local/lib/python3.12/dist-packages (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (2.44.0)
# Requirement already satisfied: rich>=13.7.1 in /usr/local/lib/python3.12/dist-packages (from rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (13.9.4)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile>=0.12.1->mistral_common>=1.8.2->mistral_common[audio,image]>=1.8.2->vllm>=0.11.0->vllm_plamo3==0.0.0) (2.0.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.15.1->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (1.5.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile>=0.12.1->mistral_common>=1.8.2->mistral_common[audio,image]>=1.8.2->vllm>=0.11.0->vllm_plamo3==0.0.0) (2.23)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.7.1->rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.7.1->rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.7.1->rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]>=0.115.0->vllm>=0.11.0->vllm_plamo3==0.0.0) (0.1.2)

# %%
# !hf auth login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     A token is already saved on your machine. Run `hf auth whoami` to get more information or `hf auth logout` if you want to log out.
#     Setting a new token will erase the existing one.
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) n
# Token is valid (permission: read).
# The token `plamo3` has been saved to /root/.cache/huggingface/stored_tokens
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `plamo3`

# %%
import vllm
model = vllm.LLM("pfnet/plamo-3-nict-2b-base", trust_remote_code=True)
# Out:
# INFO 11-14 13:08:17 [__init__.py:216] Automatically detected platform cuda.
# INFO 11-14 13:08:25 [utils.py:233] non-default args: {'trust_remote_code': True, 'disable_log_stats': True, 'model': 'pfnet/plamo-3-nict-2b-base'}
# The argument `trust_remote_code` is to be used with Auto classes. It has no effect here and is ignored.
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# INFO 11-14 13:08:45 [model.py:547] Resolved architecture: Plamo3ForCausalLM
# `torch_dtype` is deprecated! Use `dtype` instead!
# INFO 11-14 13:08:45 [model.py:1510] Using max model len 4096
# INFO 11-14 13:08:45 [scheduler.py:205] Chunked prefill is enabled with max_num_batched_tokens=8192.
# WARNING 11-14 13:08:50 [tokenizer.py:253] Using a slow tokenizer. This might cause a significant slowdown. Consider using a fast tokenizer instead.
# WARNING 11-14 13:08:53 [__init__.py:3036] We must use the `spawn` multiprocessing start method. Overriding VLLM_WORKER_MULTIPROC_METHOD to 'spawn'. See https://docs.vllm.ai/en/latest/usage/troubleshooting.html#python-multiprocessing for more information. Reasons: CUDA is initialized
# INFO 11-14 13:09:44 [llm.py:306] Supported_tasks: ['generate']

# %%
response = model.generate(
    prompts=["これからの人工知能技術は"],
    sampling_params=vllm.SamplingParams(
        n=1,
        max_tokens=32,
        top_k=50,
        top_p=0.95,
        temperature=1.0,
    ),
)[0]
generated_text = response.outputs[0].text
print(generated_text)
# Out:
# Adding requests:   0%|          | 0/1 [00:00<?, ?it/s]
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# AIによる画像認識が主流になるといわれている。自動運転などはすでに実用化されている自動車が事故にあわない為の技術として人工知能が使われている。
# 例えば自動車が障害物を
